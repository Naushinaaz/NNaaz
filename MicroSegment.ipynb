# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Micro_Seg_Test_Datasource.csv")
# Out:
# C:\Users\nNaaz\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Selling Plant Cur       Plant Chain Cur  Chain_Cust  Sold-to Customer  \
# 0               1006  Plainfield       185  S MART GAS             12303
# 1               1006  Plainfield       185  S MART GAS             12303
# 2               1006  Plainfield       185  S MART GAS             12303
# 3               1006  Plainfield       185  S MART GAS             12303
# 4               1006  Plainfield       185  S MART GAS             12303
#
#            Customer   Street Name  Cust Segment DSM - NBD Cur  \
# 0  GAS CITY I SHELL  6271 E 500 S  Independents    Brent Shay
# 1  GAS CITY I SHELL  6271 E 500 S  Independents    Brent Shay
# 2  GAS CITY I SHELL  6271 E 500 S  Independents    Brent Shay
# 3  GAS CITY I SHELL  6271 E 500 S  Independents    Brent Shay
# 4  GAS CITY I SHELL  6271 E 500 S  Independents    Brent Shay
#
#        DSM - RCS Cur     ...        States Postal Code Cur Tax Area Cur  \
# 0  Richard VonBargen     ...       Indiana           46933            4
# ...

# %%
df.columns
# Out:
# Index(['Selling Plant Cur', 'Plant', 'Chain Cur', 'Chain_Cust',
#        'Sold-to Customer', 'Customer', 'Street Name', 'Cust Segment',
#        'DSM - NBD Cur', 'DSM - RCS Cur', 'Customer Group', 'City Cur',
#        'County Cur', 'Region Cur', 'States', 'Postal Code Cur', 'Tax Area Cur',
#        'NACS Category', 'FineLines', 'Fiscal year/period',
#        'Blended Qty-Sales UOM', 'Customer Net Price', 'BAC - Best Acq Cost',
#        'Figured Cost'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Selling Plant Cur          int64
# Plant                     object
# Chain Cur                 object
# Chain_Cust                object
# Sold-to Customer           int64
# Customer                  object
# Street Name               object
# Cust Segment              object
# DSM - NBD Cur             object
# DSM - RCS Cur             object
# Customer Group            object
# City Cur                  object
# County Cur                object
# Region Cur                object
# States                    object
# Postal Code Cur            int64
# Tax Area Cur               int64
# NACS Category              int64
# FineLines                 object
# Fiscal year/period        object
# Blended Qty-Sales UOM    float64
# Customer Net Price       float64
# BAC - Best Acq Cost      float64
# Figured Cost             float64
# dtype: object

# %%
plant=df.groupby(['FineLines','Plant','States']).sum().sort_values('Customer Net Price',ascending=False)

# %%
plant
# Out:
#                                                           Selling Plant Cur  \
# FineLines                  Plant          States
# Cigarettes                 Montgomery     Illinois                  5402397
#                            Rockmart       Georgia                   4874688
#                            Ypsilanti      Michigan                  3906435
#                            Plainfield     Indiana                   1698128
#                            Springfield    Ohio                      1804544
#                            Pittsburgh     Pennsylvania              1243584
#                                           Ohio                       961136
#                            Montgomery     Indiana                    680680
#                                           Wisconsin                  939939
#                            Eau Claire     Minnesota                  788029
#                                           Wisconsin                  774912
# ...

# %%
df.groupby('States').sum().sort_values('Customer Net Price',ascending=False)
# Out:
#                 Selling Plant Cur  Sold-to Customer  Postal Code Cur  \
# States
# Illinois                 60227282        1518897540       3648970772
# Ohio                     39753604        1123309758       1740855188
# Georgia                  53969328        1515033351       1624695066
# Indiana                  28259489         720672872       1309531038
# Michigan                 44104769         945283304       2126523978
# Wisconsin                19145531         521153553       1025356259
# Pennsylvania             19043868         600830067        304216015
# Minnesota                12035352         353902780        660077853
# Tennessee                 8428896         246651509        313539063
# Alabama                   4927104         142403949        174054751
# Kentucky                  4328598         137613906        173833934
# Maryland                  3521456         110616386         73784457
# ...

# %%
df.groupby('FineLines').sum().sort_values('Customer Net Price',ascending=False)
# Out:
#                             Selling Plant Cur  Sold-to Customer  \
# FineLines
# Cigarettes                           26747992         719546976
# Other Tobacco                        24893762         668140065
# Candy                                25262621         677143639
# Salty Snacks                         24125585         645653158
# Alternative Snacks                   22574342         603235987
# Packaged Sweet Snacks                23128477         618392862
# Health & Beauty Care                 18505171         489647467
# Store Use/Supply                     10509326         270257599
# Fdsrv prepared on-site                7490378         207489885
# Hot Dispensed Beverages               8601604         224188301
# Pack Bev Non Alcoholic               14369144         379669304
# Automotive Products                  13334517         355459140
# Edible Grocery                       17580043         470080284
# ...

# %%
df.groupby('FineLines').sum().sort_values('Customer Net Price',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a4d38a667dfa> in <module>()
# ----> 1 plant[[df.groupby('FineLines').sum().sort_values('Customer Net Price',ascending=False)]]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2158     def _getitem_array(self, key):
#    2159         # also raises Exception if object array with NA values
# -> 2160         if com.is_bool_indexer(key):
# ...
