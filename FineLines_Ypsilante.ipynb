# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./File_for_python_Test1.csv")

# %%
df.shape
# Out:
# (3449, 14)

# %%
df.head()
# Out:
#    FineLines               Cust_names CNP_2017 CNP_2018  BAC_2017 BAC_2018  \
# 0  Mobil One              BOGGS GAS#2    52.54      NaN     43.04      NaN
# 1  Mobil One               M-24 MOBIL      NaN    26.74       NaN    22.33
# 2  Mobil One  HEATHER ENTERPRISES INC        0      NaN     -0.02      NaN
# 3  Mobil One               I FUEL INC      NaN       27       NaN    22.33
# 4  Mobil One      REEMS MINI MART INC      NaN   -22.86       NaN   -22.32
#
#   FC_2017 FC_2018  Profit_2017  Profit_2018 PPU_2017 PPU_2018 PM_2017 PM_2018
# 0   50.04     NaN         9.50          NaN     4.75      NaN  0.1808     NaN
# 1     NaN   25.96          NaN         4.41      NaN     4.41     NaN  0.1649
# 2       0     NaN         0.02          NaN        X      NaN       X     NaN
# 3     NaN   25.96          NaN         4.67      NaN     4.67     NaN   0.173
# 4     NaN  -25.98          NaN        -0.54      NaN     0.54     NaN  0.0236

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.replace('X', np.nan)
# Out:
#                   FineLines                         Cust_names CNP_2017  \
# 0                 Mobil One                        BOGGS GAS#2    52.54
# 1                 Mobil One                         M-24 MOBIL      NaN
# 2                 Mobil One            HEATHER ENTERPRISES INC        0
# 3                 Mobil One                         I FUEL INC      NaN
# 4                 Mobil One                REEMS MINI MART INC      NaN
# 5                 Mobil One                   MAPLE POINTE GAS     51.8
# 6                 Mobil One                  RAPID STOP SUNOCO      NaN
# 7                  Pennzoil          BROWNS MARKET PLACE #1200    25.76
# 8                  Pennzoil                    SAW DUST CORNER    55.04
# 9                  Pennzoil                  CLEAR LAKE OIL CO    14.07
# 10                 Pennzoil            PIERSON SERVICE STATION      NaN
# 11                 Pennzoil                    BRIGHTON MARKET    25.14
# ...

# %%
df.fillna('X', inplace=True)

# %%
df.drop('Cust_names',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# FineLines      object
# CNP_2017       object
# CNP_2018       object
# BAC_2017       object
# BAC_2018       object
# FC_2017        object
# FC_2018        object
# Profit_2017    object
# Profit_2018    object
# PPU_2017       object
# PPU_2018       object
# PM_2017        object
# PM_2018        object
# dtype: object

# %%
df = df.convert_objects(convert_numeric=True)
# Out:
# C:\Users\nNaaz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby(["FineLines"]).sum().sort_values("PM_2017", ascending=False)
# Out:
#                                           CNP_2017  CNP_2018  BAC_2017  \
# FineLines
# CValet Automotive Other                    8878.03   8959.54   7124.04
# Misc Oil                                  25000.32  21333.69  16183.16
# Fuel Injector Cleaners                     5754.94   5870.21   3856.77
# Power Steering Fluids                      5798.73   5251.14   4599.28
# Little Tree                                9097.95  11327.81   7630.20
# STP Brake Fluid                            3282.14   3004.46   2474.89
# Gas Additives                              5808.87   7394.78   4749.40
# Oil Treatment                              1167.08   1293.36    766.06
# Tire Inflators/Repair                      6839.90   6922.53   5858.79
# Armor All                                  2322.97   2535.76   1825.42
# Little Auto Automotive Other               2027.07   1566.09   1662.41
# Starting Fluid                             1528.18   1863.29   1304.96
# ...

# %%
data_2017=df.groupby("FineLines").sum().plot(kind='bar')
data_2017.set_xlabel("FineLines")
data_2017.set_ylabel("PM_2017")
# Out:
# Text(0,0.5,'PM_2017')

# %%
df['MarDiff']=df['PM_2018']-df['PM_2017']

# %%
sort_MD=df.groupby(["FineLines"]).sum().sort_values("MarDiff", ascending=False)

# %%
sort_MD
# Out:
#                                           CNP_2017  CNP_2018  BAC_2017  \
# FineLines
# CValet Automotive Other                    8878.03   8959.54   7124.04
# Little Auto Automotive Other               2027.07   1566.09   1662.41
# Tire Inflators/Repair                      6839.90   6922.53   5858.79
# Fuel Injector Cleaners                     5754.94   5870.21   3856.77
# Little Tree                                9097.95  11327.81   7630.20
# Peak                                      11824.64  12120.05  11109.18
# Heet                                       1058.37   1839.57    921.84
# Diesel Treatments                          3889.32   3400.60   3316.80
# Misc Motor Oil                             3437.41   3900.50   3575.25
# Misc Anti-Freeze/Coolants/Window Solvent   6502.71  11076.50   6583.97
# Armor All                                  2322.97   2535.76   1825.42
# Speedway Contract Motor Oil                  73.07    166.43     60.57
# ...

# %%
margin_out=sort_MD[sort_MD['MarDiff']<0].sort_values('MarDiff',ascending =True)

# %%
margin_out
# Out:
#                             CNP_2017  CNP_2018  BAC_2017  BAC_2018   FC_2017  \
# FineLines
# STP Brake Fluid              3282.14   3004.46   2474.89   2421.40   3068.16
# Power Steering Fluids        5798.73   5251.14   4599.28   4273.03   5356.38
# Misc Oil                    25000.32  21333.69  16183.16  15697.98  23457.41
# Oil Treatment                1167.08   1293.36    766.06    895.70   1085.98
# Wndshld De-icers/Lock Thaw    148.67    423.37    125.52    362.50    135.69
# Gas Additives                5808.87   7394.78   4749.40   6131.76   5306.94
# Misc Car Care Chemicals      1324.27   1330.46   1110.88   1139.64   1183.72
# Starting Fluid               1528.18   1863.29   1304.96   1623.79   1315.76
# Misc Transmission Fluid       322.56    290.34    276.75    252.64    287.20
# Pennzoil                    14451.48  10389.66  13218.21   9494.70  12918.88
# Trans Stop Leak               199.01    321.04    170.50    279.82    189.20
# ...

# %%
margin_out1=margin_out[['CNP_2017','CNP_2018','MarDiff']]

# %%
margin_out1.index
# Out:
# Index(['STP Brake Fluid', 'Power Steering Fluids', 'Misc Oil', 'Oil Treatment',
#        'Wndshld De-icers/Lock Thaw', 'Gas Additives',
#        'Misc Car Care Chemicals', 'Starting Fluid', 'Misc Transmission Fluid',
#        'Pennzoil', 'Trans Stop Leak', 'Shell', 'Misc Air Fresh',
#        'Other Gas Cans', 'Misc Additives', 'Misc Brake Fluid',
#        'Autoguard Additives'],
#       dtype='object', name='FineLines')

# %%
margin_out1.plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-0ba8fa9ed16f> in <module>()
#       1 margin_out1.plot(kind='bar')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
margin_out.count()
